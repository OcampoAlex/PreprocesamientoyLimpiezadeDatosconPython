# %%
import pandas as pd #Kevin Alejandro Ocampo Juarez ICO

# %%
! pip install mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: mysql-connector-python in d:\anaconda\lib\site-packages (8.0.33)
# Requirement already satisfied: sqlalchemy in d:\anaconda\lib\site-packages (1.4.39)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in d:\anaconda\lib\site-packages (from mysql-connector-python) (3.20.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy) (2.0.1)

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegiosource'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegiosource?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM Alumnos WHERE DATE(fnac) >=  %s'''
df_mysql =pd.read_sql_query(sql=sql, con=conn, params=['2000-01-01'])

# %%
df_mysql
# Out:
#   no_cuenta  nombre    paterno       fnac  estatura
# 0        1A    Juan      Lopez 2001-01-01      1.78
# 1       1GG   Maria  Paterno 1 2001-03-20      1.60
# 2      21OL   Donna      River 2002-01-09      1.69
# 3       2GG   Maria  Paterno 2 2001-03-20      1.62
# 4        3B   Perla     Calles 2001-01-20      1.60
# 5        4A  Carlos     Madero 2001-01-01      1.68
# 6       574   Pedro  Paterno 5 2022-01-31      1.60
# 7        6C   Jesus     Garcia 2001-03-20      1.65
# 8        7B    Gema       None 2001-03-20      1.53
# 9      A744   Amaro     Garcia 2001-09-23      1.83

# %%
! pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.4.0-cp310-cp310-win_amd64.whl (453 kB)
#      -------------------------------------- 453.6/453.6 kB 2.8 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ------------------------------------- 283.7/283.7 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.4.0

# %%
import pymongo

# %%
usuario = 'fesalu'
passwd = 'nosqlfes123'
cluster = 'cluster0-shard-00-00.8pyt4.mongodb.net'
n1 = 'cluster0-shard-00-01.8pyt4.mongodb.net'
n2 = 'cluster0-shard-00-02.8pyt4.mongodb.net'
puerto = '27017'
mongo_str = f"mongodb://{usuario}:{passwd}@{cluster}:{puerto},{n1}:{puerto},{n2}:{puerto}/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority"
print(mongo_str)
mongoClient = pymongo.MongoClient(mongo_str)
mongoClient
# Out:
# mongodb://fesalu:nosqlfes123@cluster0-shard-00-00.8pyt4.mongodb.net:27017,cluster0-shard-00-01.8pyt4.mongodb.net:27017,cluster0-shard-00-02.8pyt4.mongodb.net:27017/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority
# MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True)

# %%
#ver las BD disponibles
mongoClient.list_database_names()
# Out:
# ['OmarMendozaGonzalez',
#  'agenda',
#  'colegio',
#  'fundamentosmongo',
#  'itsa',
#  'pdcd',
#  'taller',
#  'tbd',
#  'tebd',
#  'admin',
#  'local']

# %%
db = mongoClient.colegio
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'colegio')

# %%
f = db.alumnos.find({'curp': {'$exists': 1}}) #f es un objeto cursor
f

# %%
lista_f = list(f) #Convertimos el cursor 'f' en una lista de diccionarios

# %%
df_mongo = pd.DataFrame(lista_f)
type(df_mongo)
# Out:
# pandas.core.frame.DataFrame

# %%
df_mongo
# Out:
#                           _id  clave_alu ap_paterno ap_materno  \
# 0    5f873e4a7591b0b48f65faf7   11030178     GARCIA      GOMEZ
# 1    5f873e4a7591b0b48f65fb01   11030207    AGUILAR  ZAMARRIPA
# 2    5f873e4a7591b0b48f65fb02   11030208    ALVAREZ    PADILLA
# 3    5f873e4a7591b0b48f65faf8   11030180  GUTIERREZ     FLORES
# 4    5f873e4a7591b0b48f65fafd   11030201     SUAREZ    SANCHEZ
# ..                        ...        ...        ...        ...
# 602  5f873e4a7591b0b48f65fe18   11080199    RAMIREZ  LEGORRETA
# 603  5f873e4a7591b0b48f65fe07   11080201       SOTO      ELIAS
# 604  5f873e4a7591b0b48f65fe0c   11080206       NAVA     TORRES
# 605  5f873e4a7591b0b48f65fe00   11080189    HERRERA     MENDEZ
# 606  62852acbdee309a4a8124bc2   22000001    MENDOZA   GONZALEZ
#
#               nombre sexo                curp                 ciudad  \
# 0             RAFAEL    M     220140190055288              QUERETARO
# 1    MICHELLE IVONNE    F  AUZM810928MQTGMC00              QUERETARO
# 2      JOSE DE JESUS  NaN  AAPJ810713HMNLDS00              QUERETARO
# 3       CARLOS DAVID    M  GUFC810124HDFTLR00              QUERETARO
# 4              OSCAR    M  SUSO811025HQTRNS00              QUERETARO
# ..               ...  ...                 ...                    ...
# 602  ANGELA CAROLINA  NaN  RALA930820MDFMGN00                    NaN
# 603   PALOMA DENISSE    F  SOEP821030MQTTLL00              QUERETARO
# 604   LEONARDO JESUS    M    NATL9408HDFVRN00              QUERETARO
# 605   FATIMA CELESTE  NaN  HEMF821117MQTRNT00  SANTIAGO DE QUERETARO
# 606             OMAR  NaN                MEGO                TEXCOCO
#
#                              email  \
# 0    arobertogarcia@prodigy.net.mx
# 1                              NaN
# 2              quepedo27@email.com
# 3           chorok_skp91@email.com
# 4                 ossuarez@aol.com
# ..                             ...
# 602                            NaN
# 603      chiquis_palomit@email.com
# 604      leo94-88@infinitum.com.mx
# 605      chikita_girl_yo@email.com
# 606                   mi@email.com
#
#                                              edad materias evaluaciones
# 0                                             NaN      NaN          NaN
# 1    {'anios': 29.0, 'meses': 11.0, 'dias': 25.0}      NaN          NaN
# 2     {'anios': 30.0, 'meses': 2.0, 'dias': 10.0}      NaN          NaN
# 3     {'anios': 30.0, 'meses': 7.0, 'dias': 30.0}      NaN          NaN
# 4    {'anios': 29.0, 'meses': 10.0, 'dias': 29.0}      NaN          NaN
# ..                                            ...      ...          ...
# 602    {'anios': 28.0, 'meses': 1.0, 'dias': 3.0}      NaN          NaN
# 603  {'anios': 28.0, 'meses': 10.0, 'dias': 23.0}      NaN          NaN
# 604                                           NaN      NaN          NaN
# 605   {'anios': 28.0, 'meses': 10.0, 'dias': 5.0}      NaN          NaN
# 606        {'anios': 44, 'meses': 10, 'dias': 10}      NaN          NaN
#
# [607 rows x 12 columns]

# %%
f = db.alumnos.find({'curp': {'$exists': 0}}) #f es un objeto cursor
f

# %%
lista_f = list(f)

# %%
df_mongo = pd.DataFrame(lista_f)
type(df_mongo)
# Out:
# pandas.core.frame.DataFrame

# %%
df_mongo
# Out:
#                           _id  clave_alu ap_paterno ap_materno         nombre  \
# 0    5f873e4a7591b0b48f65faf9   11030177   FERRUSCA    ANDRADE        OCTAVIO
# 1    5f873e4a7591b0b48f65faf6   11030172   BORBOLLA      RAMOS        ARGELIA
# 2    5f873e4a7591b0b48f65fafc   11030199    ROSALES     APREZA  NESTOR MARTIN
# 3    5f873e4a7591b0b48f65fb04   11030217   FERRUSCA    ANDRADE          CESAR
# 4    5f873e4a7591b0b48f65fafb   11030173     CASTRO    MANCERA  KARLA MARIANA
# ..                        ...        ...        ...        ...            ...
# 197  5f873e4a7591b0b48f65fe1a   14080001      MEJIA    JIMENEZ          LUISA
# 198  5f873e4a7591b0b48f65fe1d   12080001
# 199  5f873e4a7591b0b48f65fe19   14080002      MEJIA    JIMENEZ          LUISA
# 200  5f873e4a7591b0b48f65fe1b   14080003      MEJIA    JIMENEZ          LUISA
# 201  5f873e4a7591b0b48f65fe1c   14080004      MEJIA    JIMENEZ          LUISA
#
#     sexo                 ciudad                    email materias evaluaciones
# 0      M              QUERETARO  tavoferrus_11@email.com      NaN          NaN
# 1      F              QUERETARO    kargi_gogos@email.com      NaN          NaN
# 2      M              QUERETARO     nestoriwh@hotmai.com      NaN          NaN
# 3      M              QUERETARO    cesar_tum-b@email.com      NaN          NaN
# 4      F  SANTIAGO DE QUERETARO                      NaN      NaN          NaN
# ..   ...                    ...                      ...      ...          ...
# 197  NaN                    NaN                      NaN      NaN          NaN
# 198  NaN                    NaN                      NaN      NaN          NaN
# 199  NaN                    NaN                      NaN      NaN          NaN
# 200  NaN                    NaN                      NaN      NaN          NaN
# 201  NaN                    NaN                      NaN      NaN          NaN
#
# [202 rows x 10 columns]

# %%
url = 'https://es.wikipedia.org/wiki/ISO_3166-2:MX'
df_html = pd.read_html(url)
print(type(df_html))
df_html
# Out:
# <class 'list'>
# [                                               Estado  \
#  0                                      Aguascalientes
#  1                                     Baja California
#  2                                 Baja California Sur
#  3                                            Campeche
#  4                                             Chiapas
#  5                                           Chihuahua
#  6                                    Ciudad de México
#  7                                            Coahuila
#  8                                              Colima
#  9                                             Durango
#  10                                         Guanajuato
#  11                                           Guerrero
#  12                                            Hidalgo
#  13                                            Jalisco
#  14                                             México
#  15                                          Michoacán
#  16                                            Morelos
#  17                                            Nayarit
#  18                                         Nuevo León
#  19                                             Oaxaca
#  20                                             Puebla
#  21                                          Querétaro
#  22                                       Quintana Roo
#  23                                    San Luis Potosí
#  24                                            Sinaloa
#  25                                             Sonora
#  26                                            Tabasco
#  27                                         Tamaulipas
#  28                                           Tlaxcala
#  29                                           Veracruz
#  30                                            Yucatán
#  31                                          Zacatecas
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                               Variable  \
#  0                                                Ags.
#  1                                                B.C.
#  2                                              B.C.S.
#  3                                               Camp.
#  4                                               Chis.
#  5                                               Chih.
#  6                                             C.D.Mx.
#  7                                               Coah.
#  8                                                Col.
#  9                                                Dgo.
#  10                                               Gto.
#  11                                               Gro.
#  12                                               Hgo.
#  13                                               Jal.
#  14                                      Edo. Méx.[D]​
#  15                                              Mich.
#  16                                               Mor.
#  17                                               Nay.
#  18                                               N.L.
#  19                                               Oax.
#  20                                               Pue.
#  21                                               Qro.
#  22                                        Q. Roo.[F]​
#  23                                             S.L.P.
#  24                                               Sin.
#  25                                               Son.
#  26                                               Tab.
#  27                                             Tamps.
#  28                                              Tlax.
#  29                                               Ver.
#  30                                               Yuc.
#  31                                               Zac.
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             RENAPO[A]​  \
#  0                                                  AS
#  1                                                  BC
#  2                                                  BS
#  3                                                  CC
#  4                                                  CS
#  5                                                  CH
#  6                                                  DF
#  7                                                  CL
#  8                                                  CM
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                                 MC
#  15                                                 MN
#  16                                                 MS
#  17                                                 NT
#  18                                                 NL
#  19                                                 OC
#  20                                                 PL
#  21                                                 QO
#  22                                                 QR
#  23                                                 SP
#  24                                                 SL
#  25                                                 SR
#  26                                                 TC
#  27                                                 TS
#  28                                                 TL
#  29                                                 VZ
#  30                                                 YN
#  31                                                 ZS
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             Dos letras  \
#  0                                                  AG
#  1                                                  BC
#  2                                                  BS
#  3                                                  CM
#  4                                                  CS
#  5                                                  CH
#  6                                              CX[B]​
#  7                                                  CO
#  8                                                  CL
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                             EM[E]​
#  15                                                 MI
#  16                                                 MO
#  17                                                NaN
#  18                                                 NL
#  19                                                 OA
#  20                                                 PU
#  21                                                 QT
#  22                                                 QR
#  23                                                 SL
#  24                                                 SI
#  25                                                 SO
#  26                                                 TB
#  27                                                 TM
#  28                                                 TL
#  29                                                 VE
#  30                                                 YU
#  31                                                 ZA
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                  Completo (ISO 3166-2)
#  0                                              MX-AGU
#  1                                              MX-BCN
#  2                                              MX-BCS
#  3                                              MX-CAM
#  4                                              MX-CHP
#  5                                              MX-CHH
#  6                                          MX-CMX[C]​
#  7                                              MX-COA
#  8                                              MX-COL
#  9                                              MX-DUR
#  10                                             MX-GUA
#  11                                             MX-GRO
#  12                                             MX-HID
#  13                                             MX-JAL
#  14                                             MX-MEX
#  15                                             MX-MIC
#  16                                             MX-MOR
#  17                                             MX-NAY
#  18                                             MX-NLE
#  19                                             MX-OAX
#  20                                             MX-PUE
#  21                                             MX-QUE
#  22                                             MX-ROO
#  23                                             MX-SLP
#  24                                             MX-SIN
#  25                                             MX-SON
#  26                                             MX-TAB
#  27                                             MX-TAM
#  28                                             MX-TLA
#  29                                             MX-VER
#  30                                             MX-YUC
#  31                                             MX-ZAC
#  32  Notas: ↑ Registro Nacional de Población México...  ,
#                          0                                   1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q28197]

# %%
print(type(df_html[0]))
df_html[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                  Estado       Variable RENAPO[A]​ Dos letras  \
# 0        Aguascalientes           Ags.         AS         AG
# 1       Baja California           B.C.         BC         BC
# 2   Baja California Sur         B.C.S.         BS         BS
# 3              Campeche          Camp.         CC         CM
# 4               Chiapas          Chis.         CS         CS
# 5             Chihuahua          Chih.         CH         CH
# 6      Ciudad de México        C.D.Mx.         DF     CX[B]​
# 7              Coahuila          Coah.         CL         CO
# 8                Colima           Col.         CM         CL
# 9               Durango           Dgo.         DG         DG
# 10           Guanajuato           Gto.         GT         GT
# 11             Guerrero           Gro.         GR         GR
# 12              Hidalgo           Hgo.         HG         HG
# 13              Jalisco           Jal.         JC         JC
# 14               México  Edo. Méx.[D]​         MC     EM[E]​
# 15            Michoacán          Mich.         MN         MI
# 16              Morelos           Mor.         MS         MO
# 17              Nayarit           Nay.         NT        NaN
# 18           Nuevo León           N.L.         NL         NL
# 19               Oaxaca           Oax.         OC         OA
# 20               Puebla           Pue.         PL         PU
# 21            Querétaro           Qro.         QO         QT
# 22         Quintana Roo    Q. Roo.[F]​         QR         QR
# 23      San Luis Potosí         S.L.P.         SP         SL
# 24              Sinaloa           Sin.         SL         SI
# 25               Sonora           Son.         SR         SO
# 26              Tabasco           Tab.         TC         TB
# 27           Tamaulipas         Tamps.         TS         TM
# 28             Tlaxcala          Tlax.         TL         TL
# 29             Veracruz           Ver.         VZ         VE
# 30              Yucatán           Yuc.         YN         YU
# 31            Zacatecas           Zac.         ZS         ZA
#
#    Completo (ISO 3166-2)
# 0                 MX-AGU
# 1                 MX-BCN
# 2                 MX-BCS
# 3                 MX-CAM
# 4                 MX-CHP
# 5                 MX-CHH
# 6             MX-CMX[C]​
# 7                 MX-COA
# 8                 MX-COL
# 9                 MX-DUR
# 10                MX-GUA
# 11                MX-GRO
# 12                MX-HID
# 13                MX-JAL
# 14                MX-MEX
# 15                MX-MIC
# 16                MX-MOR
# 17                MX-NAY
# 18                MX-NLE
# 19                MX-OAX
# 20                MX-PUE
# 21                MX-QUE
# 22                MX-ROO
# 23                MX-SLP
# 24                MX-SIN
# 25                MX-SON
# 26                MX-TAB
# 27                MX-TAM
# 28                MX-TLA
# 29                MX-VER
# 30                MX-YUC
# 31                MX-ZAC

# %%
print(df_html[0].index)           #Marca error porque lo ejecuté dos veces y ya eliminó el registro 32
df_html[0].drop(32, axis=0, inplace=True)
df_html
# Out:
# RangeIndex(start=0, stop=32, step=1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 2
#       1 print(df_html[0].index)
# ----> 2 df_html[0].drop(32, axis=0, inplace=True)
#       3 df_html
#
# File d:\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File d:\Anaconda\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File d:\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File d:\Anaconda\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File d:\Anaconda\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File d:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: '[32] not found in axis'

# %%
url1 = 'https://en.wikipedia.org/w/index.php?title=Solar_power&oldid=1022764142'
df_html2 = pd.read_html(url1)
print(type(df_html2))
print("Numero de tablas en DF", len(df_html2))
# Out:
# <class 'list'>
# Numero de tablas en DF 22

# %%
df_html2[1]
# Out:
#     Solar Electricity Generation                                \
#                             Year                  Energy (TWh)
# 0                           2004                           2.6
# 1                           2005                           3.7
# 2                           2006                           5.0
# 3                           2007                           6.8
# 4                           2008                          11.4
# 5                           2009                          19.3
# 6                           2010                          31.4
# 7                           2011                          60.6
# 8                           2012                          96.7
# 9                           2013                         134.5
# 10                          2014                         185.9
# 11                          2015                         253.0
# 12                          2016                         328.2
# 13                          2017                         442.6
# 14                          2019                         724.1
# 15  Sources:[33][34][35][36][37]  Sources:[33][34][35][36][37]
#
#
#                       % of Total
# 0                          0.01%
# 1                          0.02%
# 2                          0.03%
# 3                          0.03%
# 4                          0.06%
# 5                          0.10%
# 6                          0.15%
# 7                          0.27%
# 8                          0.43%
# 9                          0.58%
# 10                         0.79%
# 11                         1.05%
# 12                         1.31%
# 13                         1.73%
# 14                         2.68%
# 15  Sources:[33][34][35][36][37]

# %%
df_html2[2]
# Out:
#                                  Name        Country  Capacity MWp  \
# 0                 Pavagada Solar Park          India          2050
# 1           Tengger Desert Solar Park          China          1547
# 2                   Bhadla Solar Park          India          1515
# 3       Kurnool Ultra Mega Solar Park          India          1000
# 4  Datong Solar Power Top Runner Base          China          1000
# 5          Longyangxia Dam Solar Park          China           850
# 6               Rewa Ultra Mega Solar          India           750
# 7         Kamuthi Solar Power Project          India           648
# 8               Solar Star (I and II)  United States           579
# 9                    Topaz Solar Farm  United States           550
#
#    Generation GWh p.a.  Size km2  \
# 0                  NaN        53
# 1                  NaN        43
# 2                  NaN        40
# 3                  NaN        24
# 4                  NaN       NaN
# 5                  NaN        23
# 6                  NaN       NaN
# 7                  NaN      10.1
# 8               1664.0        13
# 9               1301.0  24.6[74]
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  \
# 0                                               2017
# 1                                               2016
# 2                                               2017
# 3                                               2017
# 4                                               2016
# 5                                               2015
# 6                                               2018
# 7                                               2016
# 8                                               2015
# 9                                               2014
#
#                     Ref
# 0           [2][53][54]
# 1              [55][56]
# 2          [57][58][59]
# 3                  [60]
# 4          [61][62][63]
# 5  [64][65][66][67][68]
# 6                  [69]
# 7              [70][71]
# 8              [72][73]
# 9          [75][76][77]

# %%
i=0
for dfh in df_html2:
    print(i,"---------------")
    dfh.info()
    i= i + 1
# Out:
# 0 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes
# 1 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Solar Electricity Generation, Year)          16 non-null     object
#  1   (Solar Electricity Generation, Energy (TWh))  16 non-null     object
#  2   (Solar Electricity Generation, % of Total)    16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes
# 2 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Name                                                                         10 non-null     object
#  1   Country                                                                      10 non-null     object
#  2   Capacity MWp                                                                 10 non-null     int64
#  3   Generation GWh p.a.                                                          2 non-null      float64
#  4   Size km2                                                                     8 non-null      object
#  5   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  10 non-null     int64
#  6   Ref                                                                          10 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 688.0+ bytes
# 3 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           11 non-null     object
#  1   Capacity (MW)  11 non-null     object
#  2   Location       11 non-null     object
#  3   Notes          11 non-null     object
# dtypes: object(4)
# memory usage: 480.0+ bytes
# 4 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# 5 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# 6 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes
# 7 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vteSolar energy    24 non-null     object
#  1   vteSolar energy.1  24 non-null     object
#  2   vteSolar energy.2  2 non-null      object
# dtypes: object(3)
# memory usage: 704.0+ bytes
# 8 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6 non-null      object
#  1   1       6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# 9 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# 10 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# 11 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   vteSolar power by country    8 non-null      object
#  1   vteSolar power by country.1  8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# 12 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vtePhotovoltaics    22 non-null     object
#  1   vtePhotovoltaics.1  22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
# 13 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# 14 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# 15 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
# 16 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# 17 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# 18 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   vteElectricity delivery    11 non-null     object
#  1   vteElectricity delivery.1  11 non-null     object
#  2   vteElectricity delivery.2  1 non-null      object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# 19 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# 20 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   vteRenewable energy by country and territory    9 non-null      object
#  1   vteRenewable energy by country and territory.1  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes
# 21 ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %%
i=0
for dfh in df_html2:
    print(str(i).center(60,"*"))
    dfh.info()
    i= i + 1
# Out:
# *****************************0******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes
# *****************************1******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Solar Electricity Generation, Year)          16 non-null     object
#  1   (Solar Electricity Generation, Energy (TWh))  16 non-null     object
#  2   (Solar Electricity Generation, % of Total)    16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes
# *****************************2******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Name                                                                         10 non-null     object
#  1   Country                                                                      10 non-null     object
#  2   Capacity MWp                                                                 10 non-null     int64
#  3   Generation GWh p.a.                                                          2 non-null      float64
#  4   Size km2                                                                     8 non-null      object
#  5   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  10 non-null     int64
#  6   Ref                                                                          10 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 688.0+ bytes
# *****************************3******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           11 non-null     object
#  1   Capacity (MW)  11 non-null     object
#  2   Location       11 non-null     object
#  3   Notes          11 non-null     object
# dtypes: object(4)
# memory usage: 480.0+ bytes
# *****************************4******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************5******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************6******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes
# *****************************7******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vteSolar energy    24 non-null     object
#  1   vteSolar energy.1  24 non-null     object
#  2   vteSolar energy.2  2 non-null      object
# dtypes: object(3)
# memory usage: 704.0+ bytes
# *****************************8******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6 non-null      object
#  1   1       6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# *****************************9******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************10*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************11*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   vteSolar power by country    8 non-null      object
#  1   vteSolar power by country.1  8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************12*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vtePhotovoltaics    22 non-null     object
#  1   vtePhotovoltaics.1  22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
# *****************************13*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************14*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************15*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
# *****************************16*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************17*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************18*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   vteElectricity delivery    11 non-null     object
#  1   vteElectricity delivery.1  11 non-null     object
#  2   vteElectricity delivery.2  1 non-null      object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# *****************************19*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************20*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   vteRenewable energy by country and territory    9 non-null      object
#  1   vteRenewable energy by country and territory.1  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes
# *****************************21*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %%
url2 = 'http://ingenieria.aragon.unam.mx/ico/alumnos/examenes_extraordinarios.rb'  #No hay tablas en la url
df_html3 = pd.read_html(url2)
print(type(df_html3))
print("Numero de tablas en DF", len(df_html3))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 2
#       1 url2 = 'http://ingenieria.aragon.unam.mx/ico/alumnos/examenes_extraordinarios.rb'
# ----> 2 df_html3 = pd.read_html(url2)
#       3 print(type(df_html3))
#       4 print("Numero de tablas en DF", len(df_html3))
#
# File d:\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File d:\Anaconda\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File d:\Anaconda\lib\site-packages\pandas\io\html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File d:\Anaconda\lib\site-packages\pandas\io\html.py:931, in _parser_dispatch(flavor)
#     929 if flavor in ("bs4", "html5lib"):
#     930     if not _HAS_HTML5LIB:
# --> 931         raise ImportError("html5lib not found, please install it")
#     932     if not _HAS_BS4:
#     933         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
#EJERCICIOS

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegiosource'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegiosource?auth_plugin=mysql_native_password)

# %%
#KEVIN ALEJANDRO OCAMPO JUAREZ
#MOSTRAR DF ALUMNOS DE BD COLEGIO

# %%
sql = '''SELECT * FROM Alumnos WHERE DATE(fnac) >=  %s'''
df_mysql =pd.read_sql_query(sql=sql, con=conn, params=['2000-01-01'])

# %%
df_mysql
# Out:
#   no_cuenta  nombre    paterno       fnac  estatura
# 0        1A    Juan      Lopez 2001-01-01      1.78
# 1       1GG   Maria  Paterno 1 2001-03-20      1.60
# 2      21OL   Donna      River 2002-01-09      1.69
# 3       2GG   Maria  Paterno 2 2001-03-20      1.62
# 4        3B   Perla     Calles 2001-01-20      1.60
# 5        4A  Carlos     Madero 2001-01-01      1.68
# 6       574   Pedro  Paterno 5 2022-01-31      1.60
# 7        6C   Jesus     Garcia 2001-03-20      1.65
# 8        7B    Gema       None 2001-03-20      1.53
# 9      A744   Amaro     Garcia 2001-09-23      1.83

# %%
#MOSTRAR DF DE UNA URL DIFERENTE - Kevin Alejandro Ocampo

# %%
url3 = 'https://es.wikipedia.org/wiki/Tabla_(informaci%C3%B3n)'
df_html4 = pd.read_html(url3)
print(type(df_html4))
print("Numero de tablas en DF", len(df_html4))
# Out:
# <class 'list'>
# Numero de tablas en DF 6

# %%
df_html4[1]
# Out:
#    ×  1  2  3
# 0  1  1  2  3
# 1  2  2  4  6
# 2  3  3  6  9

# %%
df_html4[2]
# Out:
#      Nombre       Radio              Masa  Signo
# 0  Mercurio  2.439,7 km  3,285 × 10^23 kg    1.0
# 1     Venus  6.051,8 km  4,867 × 10^24 kg    2.0
# 2    Tierra    6.371 km  5,972 × 10^24 kg    3.0
# 3     Marte  3.389,5 km   6,39 × 10^23 kg    4.0
# 4   Jupiter   69.911 km  1,898 × 10^27 kg    5.0
# 5   Saturno   58.232 km  5,683 × 10^26 kg    6.0
# 6     Urano   25.362 km  8,681 × 10^25 kg    7.0
# 7   Neptuno   24.622 km  1,024 × 10^26 kg    8.0
